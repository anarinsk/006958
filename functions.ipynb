# %% [markdown]
# <a href="https://colab.research.google.com/github/anarinsk/006958/blob/master/functions.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exporing Functions
#
# ## Refactoring code
#
# ## Reusable
#
# ## First class functions
# ### Passed in as arguments
# ### Returned by a function
#
# ## Decorators
#
# ## List comprehension
#
# ## Generator and Interator
#
# ## functiontools
#
# ## Create Modules

# %%
# Refactoring code 

import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

def mandel(c, z=0, max_iter=100):
    for k in range(max_iter):
        z = z*z + c
        if abs(z) > 2:
            return k
    return k
  
def mandelbrot(w, h, xl=-1.5, xu=0.5, yl=-1, yu=1):
    img = np.zeros((h, w)).astype('int')
    for i, real in enumerate(np.linspace(xl, xu, w)):
        for j, imag in enumerate(np.linspace(yl, yu, h)):
            c = complex(real, imag)
            img[j, i] = mandel(c)
    return img
  
img = mandelbrot(w=400, h=400)
plt.grid(False)
plt.imshow(img, cmap=plt.cm.jet)
pass

# %%
img = mandelbrot(w=400, h=400, xl=-0.7, xu=0.7, yl=-1.5, yu=2)
plt.grid(False)
plt.imshow(img, cmap=plt.cm.jet)

# %%
# Function as arguments 

def grad(x, f, h=0.01):
    return (f(x+h) - f(x-h)) / (2 * h)

def f(x): 
  return (x**3 + x**2) / x**3
  
grad(-3, f)
# Out:
# -0.1111123456927321
